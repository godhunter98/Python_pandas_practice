# %%
from common_imports import *

# %%
data = pd.read_csv('Datasets/12_supermarket_sales - Sheet1.csv',parse_dates=['Date'])

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
data.head()

# %%
data.dtypes

# %%
data.sample(5,random_state=2)

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
cat = []
num = []
for i in data.columns:
    if data[i].nunique() > 10:
        cat.append(i)
    else:
        num.append(i)

# %%
data['Branch']
# Out:
# 0      A
# 1      C
# 2      A
# 3      A
# 4      A
#       ..
# 995    C
# 996    B
# 997    A
# 998    A
# 999    A
# Name: Branch, Length: 1000, dtype: object

# %%
data.groupby('Branch')['Total'].sum()
# Out:
# Branch
# A    106200.3705
# B    106197.6720
# C    110568.7065
# Name: Total, dtype: float64

# %%
data['Branch'].value_counts().plot(kind='pie',autopct="%1.2f%%")
plt.show()

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
data['Payment'].value_counts().plot(kind='pie',autopct="%1.2f%%")
# Out:
# <AxesSubplot:ylabel='Payment'>

# %%
sns.displot(data['Rating'])

# %%
sns.displot(data['cogs'])

# %%
sns.kdeplot(data['cogs'])
# Out:
# <AxesSubplot:xlabel='cogs', ylabel='Density'>

# %%
sns.boxplot(data['cogs'])
# Out:
# <AxesSubplot:xlabel='cogs'>

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
data.groupby('Product line')['Quantity'].sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Product line'>

# %%
data['day_name']=data['Date'].dt.day_name()

# %%
data['day_name'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['month']=data['Date'].dt.month_name()

# %%
data['month'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
